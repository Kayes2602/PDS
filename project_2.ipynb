# %%
# !wget https://raw.githubusercontent.com/PulockDas/pd-12-resources/refs/heads/master/titanic.csv
# Out:
# --2025-02-09 12:21:15--  https://raw.githubusercontent.com/PulockDas/pd-12-resources/refs/heads/master/titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  58.89K  --.-KB/s    in 0.03s
#
# 2025-02-09 12:21:15 (1.85 MB/s) - ‘titanic.csv’ saved [60302/60302]

# %%
import pandas as pd
import random


data = {
    "Registration Number": [f"R{1001 + i}" for i in range(50)],
    "Name": [f"Student {i+1}" for i in range(50)],
    "TT-1 Marks": [random.randint(30, 100) for _ in range(50)]
}


df = pd.DataFrame(data)


df.to_csv('term-test-1-result.csv', index=False)

# %%
from google.colab import files
files.download('term-test-1-result.csv')

# %%
import pandas as pd
import random


data = {
    "Registration Number": [f"R{1001 + i}" for i in range(50)],
    "Name": [f"Student {i+1}" for i in range(50)],
    "TT-1 Marks": [random.randint(30, 100) for _ in range(50)]1
}


df_tt1 = pd.DataFrame(data)

df_tt2 = df_tt1.copy()
df_tt2['TT-2 Marks'] = [random.randint(0, 20) for _ in range(50)]


df_tt2[['Registration Number', 'Name', 'TT-2 Marks']].to_csv('term-test-2-result.csv', index=False)

# %%
import pandas as pd

df_tt1 = pd.read_csv('term-test-1-result.csv')
df_tt2 = pd.read_csv('term-test-2-result.csv')

merged_df = pd.merge(df_tt1, df_tt2, on='Registration Number')


print(merged_df)
# Out:
#    Registration Number      Name_x  TT-1 Marks      Name_y  TT-2 Marks
# 0                R1001   Student 1          88   Student 1           7
# 1                R1002   Student 2          45   Student 2           5
# 2                R1003   Student 3          95   Student 3          15
# 3                R1004   Student 4          56   Student 4          17
# 4                R1005   Student 5          31   Student 5           5
# 5                R1006   Student 6          37   Student 6          14
# 6                R1007   Student 7          52   Student 7          10
# 7                R1008   Student 8          37   Student 8          19
# 8                R1009   Student 9          46   Student 9           9
# 9                R1010  Student 10          36  Student 10          15
# 10               R1011  Student 11          37  Student 11          10
# 11               R1012  Student 12          45  Student 12          14
# 12               R1013  Student 13          36  Student 13          10
# 13               R1014  Student 14          66  Student 14          13
# 14               R1015  Student 15          78  Student 15          10
# 15               R1016  Student 16          49  Student 16           8
# 16               R1017  Student 17          61  Student 17          11
# 17               R1018  Student 18          60  Student 18           8
# 18               R1019  Student 19          91  Student 19          19
# 19               R1020  Student 20          98  Student 20          14
# 20               R1021  Student 21          57  Student 21           9
# 21               R1022  Student 22          76  Student 22           8
# 22               R1023  Student 23          88  Student 23          15
# 23               R1024  Student 24          52  Student 24           4
# 24               R1025  Student 25          94  Student 25          13
# 25               R1026  Student 26          72  Student 26           9
# 26               R1027  Student 27          35  Student 27          17
# 27               R1028  Student 28          45  Student 28           6
# 28               R1029  Student 29          90  Student 29           7
# 29               R1030  Student 30          95  Student 30          10
# 30               R1031  Student 31          97  Student 31           6
# 31               R1032  Student 32          96  Student 32          16
# 32               R1033  Student 33          66  Student 33          20
# 33               R1034  Student 34          84  Student 34          17
# 34               R1035  Student 35          95  Student 35           9
# 35               R1036  Student 36          66  Student 36          20
# 36               R1037  Student 37          51  Student 37           9
# 37               R1038  Student 38         100  Student 38          13
# 38               R1039  Student 39          46  Student 39          10
# 39               R1040  Student 40          54  Student 40           3
# 40               R1041  Student 41          84  Student 41          15
# 41               R1042  Student 42          30  Student 42           3
# 42               R1043  Student 43          54  Student 43           6
# 43               R1044  Student 44          38  Student 44           4
# 44               R1045  Student 45          43  Student 45          12
# 45               R1046  Student 46          62  Student 46          18
# 46               R1047  Student 47          81  Student 47           2
# 47               R1048  Student 48          55  Student 48          16
# 48               R1049  Student 49          61  Student 49          18
# 49               R1050  Student 50          79  Student 50          18

# %%
import pandas as pd


df_tt1 = pd.read_csv('term-test-1-result.csv')
df_tt2 = pd.read_csv('term-test-2-result.csv')

merged_df = pd.merge(df_tt1, df_tt2, on='Registration Number')

merged_df['Best TT Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)


merged_df['Average TT Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].mean(axis=1)


print(merged_df)
# Out:
#    Registration Number      Name_x  TT-1 Marks      Name_y  TT-2 Marks  \
# 0                R1001   Student 1          88   Student 1           7
# 1                R1002   Student 2          45   Student 2           5
# 2                R1003   Student 3          95   Student 3          15
# 3                R1004   Student 4          56   Student 4          17
# 4                R1005   Student 5          31   Student 5           5
# 5                R1006   Student 6          37   Student 6          14
# 6                R1007   Student 7          52   Student 7          10
# 7                R1008   Student 8          37   Student 8          19
# 8                R1009   Student 9          46   Student 9           9
# 9                R1010  Student 10          36  Student 10          15
# 10               R1011  Student 11          37  Student 11          10
# 11               R1012  Student 12          45  Student 12          14
# 12               R1013  Student 13          36  Student 13          10
# 13               R1014  Student 14          66  Student 14          13
# 14               R1015  Student 15          78  Student 15          10
# 15               R1016  Student 16          49  Student 16           8
# 16               R1017  Student 17          61  Student 17          11
# 17               R1018  Student 18          60  Student 18           8
# 18               R1019  Student 19          91  Student 19          19
# 19               R1020  Student 20          98  Student 20          14
# 20               R1021  Student 21          57  Student 21           9
# 21               R1022  Student 22          76  Student 22           8
# 22               R1023  Student 23          88  Student 23          15
# 23               R1024  Student 24          52  Student 24           4
# 24               R1025  Student 25          94  Student 25          13
# 25               R1026  Student 26          72  Student 26           9
# 26               R1027  Student 27          35  Student 27          17
# 27               R1028  Student 28          45  Student 28           6
# 28               R1029  Student 29          90  Student 29           7
# 29               R1030  Student 30          95  Student 30          10
# 30               R1031  Student 31          97  Student 31           6
# 31               R1032  Student 32          96  Student 32          16
# 32               R1033  Student 33          66  Student 33          20
# 33               R1034  Student 34          84  Student 34          17
# 34               R1035  Student 35          95  Student 35           9
# 35               R1036  Student 36          66  Student 36          20
# 36               R1037  Student 37          51  Student 37           9
# 37               R1038  Student 38         100  Student 38          13
# 38               R1039  Student 39          46  Student 39          10
# 39               R1040  Student 40          54  Student 40           3
# 40               R1041  Student 41          84  Student 41          15
# 41               R1042  Student 42          30  Student 42           3
# 42               R1043  Student 43          54  Student 43           6
# 43               R1044  Student 44          38  Student 44           4
# 44               R1045  Student 45          43  Student 45          12
# 45               R1046  Student 46          62  Student 46          18
# 46               R1047  Student 47          81  Student 47           2
# 47               R1048  Student 48          55  Student 48          16
# 48               R1049  Student 49          61  Student 49          18
# 49               R1050  Student 50          79  Student 50          18
#
#     Best TT Marks  Average TT Marks
# 0              88              47.5
# 1              45              25.0
# 2              95              55.0
# 3              56              36.5
# 4              31              18.0
# 5              37              25.5
# 6              52              31.0
# 7              37              28.0
# 8              46              27.5
# 9              36              25.5
# 10             37              23.5
# 11             45              29.5
# 12             36              23.0
# 13             66              39.5
# 14             78              44.0
# 15             49              28.5
# 16             61              36.0
# 17             60              34.0
# 18             91              55.0
# 19             98              56.0
# 20             57              33.0
# 21             76              42.0
# 22             88              51.5
# 23             52              28.0
# 24             94              53.5
# 25             72              40.5
# 26             35              26.0
# 27             45              25.5
# 28             90              48.5
# 29             95              52.5
# 30             97              51.5
# 31             96              56.0
# 32             66              43.0
# 33             84              50.5
# 34             95              52.0
# 35             66              43.0
# 36             51              30.0
# 37            100              56.5
# 38             46              28.0
# 39             54              28.5
# 40             84              49.5
# 41             30              16.5
# 42             54              30.0
# 43             38              21.0
# 44             43              27.5
# 45             62              40.0
# 46             81              41.5
# 47             55              35.5
# 48             61              39.5
# 49             79              48.5

# %%
import pandas as pd
df_tt1 = pd.read_csv('term-test-1-result.csv')
df_tt2 = pd.read_csv('term-test-2-result.csv')


merged_df = pd.merge(df_tt1, df_tt2, on='Registration Number')


merged_df['Best TT Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)


merged_df = merged_df.drop(columns=['TT-1 Marks', 'TT-2 Marks'])

print(merged_df)
# Out:
#    Registration Number      Name_x      Name_y  Best TT Marks
# 0                R1001   Student 1   Student 1             88
# 1                R1002   Student 2   Student 2             45
# 2                R1003   Student 3   Student 3             95
# 3                R1004   Student 4   Student 4             56
# 4                R1005   Student 5   Student 5             31
# 5                R1006   Student 6   Student 6             37
# 6                R1007   Student 7   Student 7             52
# 7                R1008   Student 8   Student 8             37
# 8                R1009   Student 9   Student 9             46
# 9                R1010  Student 10  Student 10             36
# 10               R1011  Student 11  Student 11             37
# 11               R1012  Student 12  Student 12             45
# 12               R1013  Student 13  Student 13             36
# 13               R1014  Student 14  Student 14             66
# 14               R1015  Student 15  Student 15             78
# 15               R1016  Student 16  Student 16             49
# 16               R1017  Student 17  Student 17             61
# 17               R1018  Student 18  Student 18             60
# 18               R1019  Student 19  Student 19             91
# 19               R1020  Student 20  Student 20             98
# 20               R1021  Student 21  Student 21             57
# 21               R1022  Student 22  Student 22             76
# 22               R1023  Student 23  Student 23             88
# 23               R1024  Student 24  Student 24             52
# 24               R1025  Student 25  Student 25             94
# 25               R1026  Student 26  Student 26             72
# 26               R1027  Student 27  Student 27             35
# 27               R1028  Student 28  Student 28             45
# 28               R1029  Student 29  Student 29             90
# 29               R1030  Student 30  Student 30             95
# 30               R1031  Student 31  Student 31             97
# 31               R1032  Student 32  Student 32             96
# 32               R1033  Student 33  Student 33             66
# 33               R1034  Student 34  Student 34             84
# 34               R1035  Student 35  Student 35             95
# 35               R1036  Student 36  Student 36             66
# 36               R1037  Student 37  Student 37             51
# 37               R1038  Student 38  Student 38            100
# 38               R1039  Student 39  Student 39             46
# 39               R1040  Student 40  Student 40             54
# 40               R1041  Student 41  Student 41             84
# 41               R1042  Student 42  Student 42             30
# 42               R1043  Student 43  Student 43             54
# 43               R1044  Student 44  Student 44             38
# 44               R1045  Student 45  Student 45             43
# 45               R1046  Student 46  Student 46             62
# 46               R1047  Student 47  Student 47             81
# 47               R1048  Student 48  Student 48             55
# 48               R1049  Student 49  Student 49             61
# 49               R1050  Student 50  Student 50             79

# %%
import pandas as pd
import random


df_tt1 = pd.read_csv('term-test-1-result.csv')
df_tt2 = pd.read_csv('term-test-2-result.csv')

merged_df = pd.merge(df_tt1, df_tt2, on='Registration Number')
merged_df['Best TT Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)
merged_df = merged_df.drop(columns=['TT-1 Marks', 'TT-2 M
merged_df['Attendance'] = [random.randint(0, 10) for _ in range(50)]
merged_df['Term Final Marks'] = [random.randint(0, 100) for _ in range(50)]


merged_df.to_csv('attendance-term-final-marks.csv', index=False)

print(merged_df)
# Out:
#    Registration Number      Name_x      Name_y  Best TT Marks  Attendance  \
# 0                R1001   Student 1   Student 1             88           1
# 1                R1002   Student 2   Student 2             45           1
# 2                R1003   Student 3   Student 3             95          10
# 3                R1004   Student 4   Student 4             56           1
# 4                R1005   Student 5   Student 5             31           4
# 5                R1006   Student 6   Student 6             37           9
# 6                R1007   Student 7   Student 7             52           6
# 7                R1008   Student 8   Student 8             37           7
# 8                R1009   Student 9   Student 9             46           3
# 9                R1010  Student 10  Student 10             36           1
# 10               R1011  Student 11  Student 11             37          10
# 11               R1012  Student 12  Student 12             45           9
# 12               R1013  Student 13  Student 13             36           8
# 13               R1014  Student 14  Student 14             66           9
# 14               R1015  Student 15  Student 15             78           7
# 15               R1016  Student 16  Student 16             49           4
# 16               R1017  Student 17  Student 17             61           1
# 17               R1018  Student 18  Student 18             60           5
# 18               R1019  Student 19  Student 19             91           5
# 19               R1020  Student 20  Student 20             98           6
# 20               R1021  Student 21  Student 21             57          10
# 21               R1022  Student 22  Student 22             76          10
# 22               R1023  Student 23  Student 23             88           7
# 23               R1024  Student 24  Student 24             52           4
# 24               R1025  Student 25  Student 25             94           7
# 25               R1026  Student 26  Student 26             72           5
# 26               R1027  Student 27  Student 27             35          10
# 27               R1028  Student 28  Student 28             45           9
# 28               R1029  Student 29  Student 29             90           4
# 29               R1030  Student 30  Student 30             95           4
# 30               R1031  Student 31  Student 31             97           1
# 31               R1032  Student 32  Student 32             96           7
# 32               R1033  Student 33  Student 33             66          10
# 33               R1034  Student 34  Student 34             84           9
# 34               R1035  Student 35  Student 35             95           9
# 35               R1036  Student 36  Student 36             66           4
# 36               R1037  Student 37  Student 37             51           2
# 37               R1038  Student 38  Student 38            100           1
# 38               R1039  Student 39  Student 39             46           7
# 39               R1040  Student 40  Student 40             54          10
# 40               R1041  Student 41  Student 41             84           0
# 41               R1042  Student 42  Student 42             30           7
# 42               R1043  Student 43  Student 43             54           1
# 43               R1044  Student 44  Student 44             38          10
# 44               R1045  Student 45  Student 45             43          10
# 45               R1046  Student 46  Student 46             62           7
# 46               R1047  Student 47  Student 47             81           6
# 47               R1048  Student 48  Student 48             55           5
# 48               R1049  Student 49  Student 49             61           9
# 49               R1050  Student 50  Student 50             79           3
#
#     Term Final Marks
# 0                 72
# 1                 37
# 2                 76
# 3                 82
# 4                 96
# 5                  7
# 6                 55
# 7                 48
# 8                 61
# 9                 52
# 10                99
# 11                53
# 12                40
# 13                12
# 14                48
# 15                40
# 16                60
# 17                53
# 18                 7
# 19                44
# 20                 5
# 21                92
# 22                 1
# 23                40
# 24                50
# 25                12
# 26                57
# 27                56
# 28                74
# 29                56
# 30                65
# 31                68
# 32                 6
# 33                63
# 34                 4
# 35                27
# 36                59
# 37                38
# 38                 6
# 39                58
# 40                83
# 41                29
# 42                57
# 43                16
# 44                45
# 45                73
# 46                19
# 47                27
# 48                 0
# 49                15

# %%
import pandas as pd


df_tt1 = pd.read_csv('term-test-1-result.csv')
df_tt2 = pd.read_csv('term-test-2-result.csv')

merged_df = pd.merge(df_tt1, df_tt2, on='Registration Number')
merged_df['Best TT Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)
merged_df = merged_df.drop(columns=['TT-1 Marks', 'TT-2 Marks'])


attendance_df = pd.read_csv('attendance-term-final-marks.csv')

final_merged_df = pd.merge(merged_df, attendance_df, on='Registration Number')


print(final_merged_df)
# Out:
#    Registration Number    Name_x_x    Name_y_x  Best TT Marks_x    Name_x_y  \
# 0                R1001   Student 1   Student 1               88   Student 1
# 1                R1002   Student 2   Student 2               45   Student 2
# 2                R1003   Student 3   Student 3               95   Student 3
# 3                R1004   Student 4   Student 4               56   Student 4
# 4                R1005   Student 5   Student 5               31   Student 5
# 5                R1006   Student 6   Student 6               37   Student 6
# 6                R1007   Student 7   Student 7               52   Student 7
# 7                R1008   Student 8   Student 8               37   Student 8
# 8                R1009   Student 9   Student 9               46   Student 9
# 9                R1010  Student 10  Student 10               36  Student 10
# 10               R1011  Student 11  Student 11               37  Student 11
# 11               R1012  Student 12  Student 12               45  Student 12
# 12               R1013  Student 13  Student 13               36  Student 13
# 13               R1014  Student 14  Student 14               66  Student 14
# 14               R1015  Student 15  Student 15               78  Student 15
# 15               R1016  Student 16  Student 16               49  Student 16
# 16               R1017  Student 17  Student 17               61  Student 17
# 17               R1018  Student 18  Student 18               60  Student 18
# 18               R1019  Student 19  Student 19               91  Student 19
# 19               R1020  Student 20  Student 20               98  Student 20
# 20               R1021  Student 21  Student 21               57  Student 21
# 21               R1022  Student 22  Student 22               76  Student 22
# 22               R1023  Student 23  Student 23               88  Student 23
# 23               R1024  Student 24  Student 24               52  Student 24
# 24               R1025  Student 25  Student 25               94  Student 25
# 25               R1026  Student 26  Student 26               72  Student 26
# 26               R1027  Student 27  Student 27               35  Student 27
# 27               R1028  Student 28  Student 28               45  Student 28
# 28               R1029  Student 29  Student 29               90  Student 29
# 29               R1030  Student 30  Student 30               95  Student 30
# 30               R1031  Student 31  Student 31               97  Student 31
# 31               R1032  Student 32  Student 32               96  Student 32
# 32               R1033  Student 33  Student 33               66  Student 33
# 33               R1034  Student 34  Student 34               84  Student 34
# 34               R1035  Student 35  Student 35               95  Student 35
# 35               R1036  Student 36  Student 36               66  Student 36
# 36               R1037  Student 37  Student 37               51  Student 37
# 37               R1038  Student 38  Student 38              100  Student 38
# 38               R1039  Student 39  Student 39               46  Student 39
# 39               R1040  Student 40  Student 40               54  Student 40
# 40               R1041  Student 41  Student 41               84  Student 41
# 41               R1042  Student 42  Student 42               30  Student 42
# 42               R1043  Student 43  Student 43               54  Student 43
# 43               R1044  Student 44  Student 44               38  Student 44
# 44               R1045  Student 45  Student 45               43  Student 45
# 45               R1046  Student 46  Student 46               62  Student 46
# 46               R1047  Student 47  Student 47               81  Student 47
# 47               R1048  Student 48  Student 48               55  Student 48
# 48               R1049  Student 49  Student 49               61  Student 49
# 49               R1050  Student 50  Student 50               79  Student 50
#
#       Name_y_y  Best TT Marks_y  Attendance  Term Final Marks
# 0    Student 1               88           1                72
# 1    Student 2               45           1                37
# 2    Student 3               95          10                76
# 3    Student 4               56           1                82
# 4    Student 5               31           4                96
# 5    Student 6               37           9                 7
# 6    Student 7               52           6                55
# 7    Student 8               37           7                48
# 8    Student 9               46           3                61
# 9   Student 10               36           1                52
# 10  Student 11               37          10                99
# 11  Student 12               45           9                53
# 12  Student 13               36           8                40
# 13  Student 14               66           9                12
# 14  Student 15               78           7                48
# 15  Student 16               49           4                40
# 16  Student 17               61           1                60
# 17  Student 18               60           5                53
# 18  Student 19               91           5                 7
# 19  Student 20               98           6                44
# 20  Student 21               57          10                 5
# 21  Student 22               76          10                92
# 22  Student 23               88           7                 1
# 23  Student 24               52           4                40
# 24  Student 25               94           7                50
# 25  Student 26               72           5                12
# 26  Student 27               35          10                57
# 27  Student 28               45           9                56
# 28  Student 29               90           4                74
# 29  Student 30               95           4                56
# 30  Student 31               97           1                65
# 31  Student 32               96           7                68
# 32  Student 33               66          10                 6
# 33  Student 34               84           9                63
# 34  Student 35               95           9                 4
# 35  Student 36               66           4                27
# 36  Student 37               51           2                59
# 37  Student 38              100           1                38
# 38  Student 39               46           7                 6
# 39  Student 40               54          10                58
# 40  Student 41               84           0                83
# 41  Student 42               30           7                29
# 42  Student 43               54           1                57
# 43  Student 44               38          10                16
# 44  Student 45               43          10                45
# 45  Student 46               62           7                73
# 46  Student 47               81           6                19
# 47  Student 48               55           5                27
# 48  Student 49               61           9                 0
# 49  Student 50               79           3                15

# %%
import pandas as pd


df_tt1 = pd.read_csv('term-test-1-result.csv')
df_tt2 = pd.read_csv('term-test-2-result.csv')


merged_df = pd.merge(df_tt1, df_tt2, on='Registration Number')


merged_df['Best TT Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)


merged_df['Average TT Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].mean(axis=1)


merged_df = merged_df.drop(columns=['TT-1 Marks', 'TT-2 Marks'])


attendance_df = pd.read_csv('attendance-term-final-marks.csv')


final_merged_df = pd.merge(merged_df, attendance_df, on='Registration Number')


final_merged_df['Final Marks'] = (final_merged_df['Term Final Marks'] * 0.7) + final_merged_df['Average TT Marks'] + final_merged_df['Attendance']


print(final_merged_df)
# Out:
#    Registration Number    Name_x_x    Name_y_x  Best TT Marks_x  \
# 0                R1001   Student 1   Student 1               88
# 1                R1002   Student 2   Student 2               45
# 2                R1003   Student 3   Student 3               95
# 3                R1004   Student 4   Student 4               56
# 4                R1005   Student 5   Student 5               31
# 5                R1006   Student 6   Student 6               37
# 6                R1007   Student 7   Student 7               52
# 7                R1008   Student 8   Student 8               37
# 8                R1009   Student 9   Student 9               46
# 9                R1010  Student 10  Student 10               36
# 10               R1011  Student 11  Student 11               37
# 11               R1012  Student 12  Student 12               45
# 12               R1013  Student 13  Student 13               36
# 13               R1014  Student 14  Student 14               66
# 14               R1015  Student 15  Student 15               78
# 15               R1016  Student 16  Student 16               49
# 16               R1017  Student 17  Student 17               61
# 17               R1018  Student 18  Student 18               60
# 18               R1019  Student 19  Student 19               91
# 19               R1020  Student 20  Student 20               98
# 20               R1021  Student 21  Student 21               57
# 21               R1022  Student 22  Student 22               76
# 22               R1023  Student 23  Student 23               88
# 23               R1024  Student 24  Student 24               52
# 24               R1025  Student 25  Student 25               94
# 25               R1026  Student 26  Student 26               72
# 26               R1027  Student 27  Student 27               35
# 27               R1028  Student 28  Student 28               45
# 28               R1029  Student 29  Student 29               90
# 29               R1030  Student 30  Student 30               95
# 30               R1031  Student 31  Student 31               97
# 31               R1032  Student 32  Student 32               96
# 32               R1033  Student 33  Student 33               66
# 33               R1034  Student 34  Student 34               84
# 34               R1035  Student 35  Student 35               95
# 35               R1036  Student 36  Student 36               66
# 36               R1037  Student 37  Student 37               51
# 37               R1038  Student 38  Student 38              100
# 38               R1039  Student 39  Student 39               46
# 39               R1040  Student 40  Student 40               54
# 40               R1041  Student 41  Student 41               84
# 41               R1042  Student 42  Student 42               30
# 42               R1043  Student 43  Student 43               54
# 43               R1044  Student 44  Student 44               38
# 44               R1045  Student 45  Student 45               43
# 45               R1046  Student 46  Student 46               62
# 46               R1047  Student 47  Student 47               81
# 47               R1048  Student 48  Student 48               55
# 48               R1049  Student 49  Student 49               61
# 49               R1050  Student 50  Student 50               79
#
#     Average TT Marks    Name_x_y    Name_y_y  Best TT Marks_y  Attendance  \
# 0               47.5   Student 1   Student 1               88           1
# 1               25.0   Student 2   Student 2               45           1
# 2               55.0   Student 3   Student 3               95          10
# 3               36.5   Student 4   Student 4               56           1
# 4               18.0   Student 5   Student 5               31           4
# 5               25.5   Student 6   Student 6               37           9
# 6               31.0   Student 7   Student 7               52           6
# 7               28.0   Student 8   Student 8               37           7
# 8               27.5   Student 9   Student 9               46           3
# 9               25.5  Student 10  Student 10               36           1
# 10              23.5  Student 11  Student 11               37          10
# 11              29.5  Student 12  Student 12               45           9
# 12              23.0  Student 13  Student 13               36           8
# 13              39.5  Student 14  Student 14               66           9
# 14              44.0  Student 15  Student 15               78           7
# 15              28.5  Student 16  Student 16               49           4
# 16              36.0  Student 17  Student 17               61           1
# 17              34.0  Student 18  Student 18               60           5
# 18              55.0  Student 19  Student 19               91           5
# 19              56.0  Student 20  Student 20               98           6
# 20              33.0  Student 21  Student 21               57          10
# 21              42.0  Student 22  Student 22               76          10
# 22              51.5  Student 23  Student 23               88           7
# 23              28.0  Student 24  Student 24               52           4
# 24              53.5  Student 25  Student 25               94           7
# 25              40.5  Student 26  Student 26               72           5
# 26              26.0  Student 27  Student 27               35          10
# 27              25.5  Student 28  Student 28               45           9
# 28              48.5  Student 29  Student 29               90           4
# 29              52.5  Student 30  Student 30               95           4
# 30              51.5  Student 31  Student 31               97           1
# 31              56.0  Student 32  Student 32               96           7
# 32              43.0  Student 33  Student 33               66          10
# 33              50.5  Student 34  Student 34               84           9
# 34              52.0  Student 35  Student 35               95           9
# 35              43.0  Student 36  Student 36               66           4
# 36              30.0  Student 37  Student 37               51           2
# 37              56.5  Student 38  Student 38              100           1
# 38              28.0  Student 39  Student 39               46           7
# 39              28.5  Student 40  Student 40               54          10
# 40              49.5  Student 41  Student 41               84           0
# 41              16.5  Student 42  Student 42               30           7
# 42              30.0  Student 43  Student 43               54           1
# 43              21.0  Student 44  Student 44               38          10
# 44              27.5  Student 45  Student 45               43          10
# 45              40.0  Student 46  Student 46               62           7
# 46              41.5  Student 47  Student 47               81           6
# 47              35.5  Student 48  Student 48               55           5
# 48              39.5  Student 49  Student 49               61           9
# 49              48.5  Student 50  Student 50               79           3
#
#     Term Final Marks  Final Marks
# 0                 72         98.9
# 1                 37         51.9
# 2                 76        118.2
# 3                 82         94.9
# 4                 96         89.2
# 5                  7         39.4
# 6                 55         75.5
# 7                 48         68.6
# 8                 61         73.2
# 9                 52         62.9
# 10                99        102.8
# 11                53         75.6
# 12                40         59.0
# 13                12         56.9
# 14                48         84.6
# 15                40         60.5
# 16                60         79.0
# 17                53         76.1
# 18                 7         64.9
# 19                44         92.8
# 20                 5         46.5
# 21                92        116.4
# 22                 1         59.2
# 23                40         60.0
# 24                50         95.5
# 25                12         53.9
# 26                57         75.9
# 27                56         73.7
# 28                74        104.3
# 29                56         95.7
# 30                65         98.0
# 31                68        110.6
# 32                 6         57.2
# 33                63        103.6
# 34                 4         63.8
# 35                27         65.9
# 36                59         73.3
# 37                38         84.1
# 38                 6         39.2
# 39                58         79.1
# 40                83        107.6
# 41                29         43.8
# 42                57         70.9
# 43                16         42.2
# 44                45         69.0
# 45                73         98.1
# 46                19         60.8
# 47                27         59.4
# 48                 0         48.5
# 49                15         62.0

# %%
final_merged_df.to_csv('final result.csv', index=False)

# %%
import pandas as pd
import random
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt



final_marks = final_merged_df[['Final Marks']]


k = random.randint(2, 6)


kmeans = KMeans(n_clusters=k, random_state=42)
final_merged_df['Cluster'] = kmeans.fit_predict(final_marks)


plt.figure(figsize=(8, 6))
plt.scatter(final_merged_df['Registration Number'], final_merged_df['Final Marks'], c=final_merged_df['Cluster'], cmap='viridis')
plt.xlabel('Registration Number')
plt.ylabel('Final Marks')
plt.title(f'K-Means Clustering with {k} Clusters')
plt.colorbar(label='Cluster')
plt.show()
